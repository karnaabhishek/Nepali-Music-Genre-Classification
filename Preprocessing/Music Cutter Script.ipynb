# %%
pip install pydub

# %%
import os
from pydub import AudioSegment

# %%
inputdir = '/content/drive/MyDrive/Songs Collection/rock'

# %%
for filename in os.listdir(inputdir):
  myaudio = AudioSegment.from_file(inputdir+"/"+filename, "m4a")
  clip_1 = myaudio[0:321000]
  clip_2 = myaudio[321000:591000]
  clip_3 = myaudio[591000:855000]
  clip_7 = myaudio[855000:137000]
  clip_8 = myaudio[137000:1411000]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
clip_1.export("/content/drive/MyDrive/purbeli bhaka/arunai tare.mp3", format="mp3")
clip_2.export("/content/drive/MyDrive/purbeli bhaka/himal chuli.mp3", format="mp3")
clip_3.export("/content/drive/MyDrive/purbeli bhaka/jhamke rumaal.mp3", format="mp3")
clip_7.export("/content/drive/MyDrive/purbeli bhaka/nadekhe maya.mp3", format="mp3")
clip_8.export("/content/drive/MyDrive/purbeli bhaka/uthi uthi.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='/content/drive/MyDrive/purbeli bhaka/uthi uthi.mp3'>

# %%
01 dialogue
5:30
12:11
19:15
19:42 dialogue
37:12
44:45
54:40
54:43 d
1:1:32
1:5:19
1:09:43
1:14:2
1:19:8
1:23:47
1:26:41
